# %%
import pandas as pd 


data = {
    "Calories": [432, 567, 986],
    "Duration": [46, 78, 98],
}


df = pd.DataFrame(data)

print(df)
# Out:
#    Calories  Duration
# 0       432        46
# 1       567        78
# 2       986        98

# %% [markdown]
# Locate rows

# %%
print(df.loc[0])
# Out:
# Calories    432
# Duration     46
# Name: 0, dtype: int64

# %% [markdown]
# Return a list of indexes

# %%
print(df.loc[[0, 1]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-2a30bdd1f3b6> in <module>
# ----> 1 print(df.loc[0, 1])
#
# /usr/lib/python3/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# /usr/lib/python3/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     803     def _getitem_tuple(self, tup):
#     804         try:
# --> 805             return self._getitem_lowerdim(tup)
#     806         except IndexingError:
#     807             pass
#
# /usr/lib/python3/dist-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     959                     return section
# ...
